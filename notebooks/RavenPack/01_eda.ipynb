# %% [markdown]
# # Bachelor Thesis
#
# © 2026 Yvan Richard
# University of St. Gallen, Spring Term 2026
#
# ## EDA RavenPack Data
#
# ---
# ## Foreword
#
# In this notebook, the purpose is to explore the merged RavenPack data.
# ## 1. Libraries & Data
#
# I first load the relevant libraries and data.

# %%
# libs
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# data
df = pd.read_csv("../../data/processed/main.csv")
# Out:
# /var/folders/7v/_v_y1jpx0rl056gg5rkjsw4r0000gn/T/ipykernel_18034/3892503274.py:2: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../../data/processed/main.csv")

# %% [markdown]
# I parse the date.

# %%
# date
df["date"] = pd.to_datetime(df["date"])

# %%
# summary stats
df[['num_news', 'num_news_relevant', 'ess', 'css', 'anl_chg']].describe().T
# Out:
#                        count        mean           std   min       25%  \
# num_news           1478886.0  718.750845  15695.853130  1.00  2.000000
# num_news_relevant  1129632.0  172.436430   3261.985257  1.00  1.000000
# ess                 971179.0    0.119486      0.273208 -1.00 -0.002632
# css                1478886.0    0.008351      0.043246 -0.92  0.000000
# anl_chg            1478886.0    0.000002      0.001053 -0.01  0.000000
#
#                        50%      75%         max
# num_news           7.00000  22.0000  1227408.00
# num_news_relevant  3.00000  12.0000   505680.00
# ess                0.11500   0.3000        1.00
# css                0.00506   0.0188        1.00
# anl_chg            0.00000   0.0000        0.01

# %%
# percentage of non-missing values for each control variable
control_vars = ["ess", "css", "anl_chg", "num_news", "num_news_relevant"]
for var in control_vars:
    non_missing_percentage = df[var].notna().mean() * 100
    print(f"Percentage of non-missing values for {var}: {non_missing_percentage:.2f}%")
# Out:
# Percentage of non-missing values for ess: 21.92%
# Percentage of non-missing values for css: 33.37%
# Percentage of non-missing values for anl_chg: 33.37%
# Percentage of non-missing values for num_news: 33.37%
# Percentage of non-missing values for num_news_relevant: 25.49%
