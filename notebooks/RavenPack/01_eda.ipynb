# %% [markdown]
# # Bachelor Thesis
#
# © 2026 Yvan Richard
# University of St. Gallen, Spring Term 2026
#
# ## EDA RavenPack Data
#
# ---
# ## Foreword
#
# In this notebook, the purpose is to reproduce the figure 1 in Barber et al. (2022).
# ## 1. Libraries & Data
#
# I first load the relevant libraries and data.

# %%
# libs
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# data
df = pd.read_csv("../../data/interim/RP/rp_cleaned_01.csv")

# %%
df.sort_values(by="date")
# Out:
#        ticker        date  num_news  num_news_relevant       ess       css  \
# 162271   PULM  2018-05-14       2.0                2.0 -0.240000  0.032333
# 78863     EYE  2018-05-14       4.0                2.0       NaN  0.028971
# 100085   HFBL  2018-05-14       1.0                1.0       NaN  0.000000
# 177915    SNA  2018-05-14       7.0                3.0  0.061905  0.022272
# 116413    KFY  2018-05-14      12.0               11.0 -0.510000  0.081333
# ...       ...         ...       ...                ...       ...       ...
# 51219     CPT  2020-08-14      11.0                1.0 -0.153846  0.000365
# 120449    KWR  2020-08-14       4.0                3.0 -0.077778  0.013091
# 119780     KT  2020-08-14       2.0                NaN       NaN  0.001600
# 2957      ACA  2020-08-14     119.0               12.0 -0.024815 -0.001762
# 224226    ZSL  2020-08-14      12.0                NaN       NaN -0.026417
#
#         anl_chg
# 162271      0.0
# 78863       0.0
# 100085      0.0
# 177915      0.0
# 116413      0.0
# ...         ...
# 51219       0.0
# 120449      0.0
# 119780      0.0
# 2957        0.0
# 224226      0.0
#
# [224227 rows x 7 columns]

# %%
# dimensions
df.shape
# Out:
# (224227, 7)

# %%
# unique tickers
unique_tickers = df["ticker"].unique()
print(f"nbr unique tickers: {len(unique_tickers)}")
# Out:
# nbr unique tickers: 459

# %%
# percentage of missing values
df.isna().sum() / len(df) * 100
# Out:
# ticker                0.000000
# date                  0.000000
# num_news              0.000000
# num_news_relevant    23.488251
# ess                  33.335861
# css                   0.000000
# anl_chg               0.000000
# dtype: float64
