# %% [markdown]
# # Bachelor Thesis
#
# © 2026 Yvan Richard
# University of St. Gallen, Spring Term 2026
#
# ## Reproduction of Barber et al. (2022)
#
# ---

# %% [markdown]
# ## Foreword
#
# In this notebook, the purpose is to reproduce Table II in Barber et al. (2022). The table depicts the summary statistics of the herding events.

# %% [markdown]
# ## 1. Libraries & Data
#
# I first load the relevant libraries and data.

# %%
# libs 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.ticker as ticker
import seaborn as sns
from datetime import datetime

# data
rh_herd = pd.read_csv("../../../data/processed/herding_events_only.csv")

# parses dates
rh_herd["date"] = pd.to_datetime(rh_herd["date"], format="%Y-%m-%d")

# %% [markdown]
# I print the summary statistics.

# %%
# summary stats
summary_stats = rh_herd[["users_close", "users_last", "userchg", "userratio", "prc", "size", "ret", "daily_buys", "daily_sells", "net_buys", "taq_retimb"]].describe().T
print(summary_stats)
# Out:
#               count         mean           std          min         25%  \
# users_close  1997.0  2802.086129  10467.344117   106.000000  289.000000
# users_last   1997.0  2890.633951  10760.057276   106.000000  294.000000
# userchg      1997.0   866.167752   3220.936298     6.000000   65.000000
# userratio    1997.0     1.581008      0.854837     1.044572    1.209677
# prc          1997.0    41.508144    110.173537     0.230100    7.300000
# size         1997.0     5.077657     17.919274     0.002751    0.425187
# ret          1997.0     0.026591      0.251378    -0.866667   -0.099275
# daily_buys   1996.0  2522.607715   8411.313355     1.000000  231.000000
# daily_sells  1996.0  1896.764529   5144.242517     0.000000  200.000000
# net_buys     1996.0   625.843186   3764.899453 -5413.000000  -12.000000
# taq_retimb   1996.0     0.079756      0.172202    -0.687500   -0.020405
#
#                     50%          75%            max
# users_close  632.000000  1735.000000  168920.000000
# users_last   638.000000  1786.000000  176399.000000
# userchg      174.000000   542.000000   49277.000000
# userratio      1.345773     1.623134      13.713287
# prc           19.970000    44.370000    2990.000000
# size           1.075233     3.408153     425.082693
# ret            0.010178     0.109567       2.812655
# daily_buys   606.500000  1752.750000  185252.000000
# daily_sells  529.000000  1532.000000   98927.000000
# net_buys      47.000000   248.000000   86325.000000
# taq_retimb     0.068229     0.178769       1.000000

# %%
# number of unique tickers in rh_herd
num_unique_tickers = rh_herd["ticker"].nunique()
print(f"Number of unique tickers in rh_herd: {num_unique_tickers}")
# Out:
# Number of unique tickers in rh_herd: 864
